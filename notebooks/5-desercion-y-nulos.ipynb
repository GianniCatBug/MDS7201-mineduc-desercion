# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import date
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import cm
import geopandas as gpd
import locale
import missingno as msno

locale.setlocale(locale.LC_ALL, 'es_CL')

plt.style.use("seaborn")
plt.rcParams.update({'font.size': 22})
plt.rcParams['axes.grid'] = False
sns.set(font_scale=1.5)

BASE = "/media/giani/Gianicosas/Magister/Proyecto/"

# %%
df = pd.read_csv(f"{BASE}work_data/matriz_desercion_2.csv.gz")
df.head()
# Out:
# /tmp/ipykernel_9823/1730194175.py:1: DtypeWarning: Columns (13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f"{BASE}work_data/matriz_desercion_2.csv.gz")
#    cat_periodo     codigo_unico   mrun  gen_alu  fec_nac_alu  \
# 0         2015   I498S6C132J2V1   37.0        1       197808
# 1         2015  I111S14C309J2V1  118.0        1       199102
# 2         2015    I106S3C64J4V1  253.0        1       198404
# 3         2015    I221S1C57J1V1  370.0        2       198910
# 4         2015    I176S8C59J2V1  533.0        2       198309
#
#    anio_ing_carr_ori                   tipo_inst_1    region_sede  \
# 0               2015  Centros de Formación Técnica         Biobío
# 1               2015      Institutos Profesionales  Metropolitana
# 2               2015      Institutos Profesionales  Metropolitana
# 3               2015  Centros de Formación Técnica  Metropolitana
# 4               2015      Institutos Profesionales       Coquimbo
#
#    valor_arancel          area_conocimiento acreditada_carr acreditada_inst  \
# 0       820000.0                 Tecnología   NO ACREDITADA      ACREDITADA
# 1      1390000.0  Administración y Comercio      ACREDITADA      ACREDITADA
# 2       920000.0  Administración y Comercio   NO ACREDITADA   NO ACREDITADA
# 3      1880000.0  Administración y Comercio      ACREDITADA      ACREDITADA
# 4      1190000.0                      Salud      ACREDITADA   NO ACREDITADA
#
#    desertor_1 region_colegio  tipo_ensenanza_colegio  prom_notas_media  \
# 0         0.0            NaN                     NaN               NaN
# 1         0.0             13                   310.0             4.975
# 2         1.0            NaN                     NaN               NaN
# 3         1.0             13                   310.0             5.100
# 4         0.0              4                   510.0             5.200
#
#   dependencia_colegio  cant_becas
# 0                 NaN         0.0
# 1                 3.0         0.0
# 2                 NaN         0.0
# 3                 3.0         1.0
# 4                 2.0         0.0

# %%
df.groupby("cat_periodo").size()
# Out:
# cat_periodo
# 2015    185799
# 2016    310538
# 2017    384231
# 2018    445920
# 2019    476106
# 2020    460630
# 2021    483290
# dtype: int64

# %% [markdown]
# ## % deserción

# %%
df["anio_desercion"] = df["cat_periodo"] + 1
df_desercion = df[["anio_desercion", "codigo_unico", "mrun", "desertor_1"]].drop_duplicates()
df.shape, df_desercion.shape
# Out:
# ((2746514, 19), (2746514, 4))

# %%
n_desertores = df_desercion.groupby(["anio_desercion"]).agg(n_desertores = ("desertor_1", "sum")).reset_index()
n_matriculados = df_desercion.groupby(["anio_desercion"]).size().reset_index(name="n_matriculados")
porc_dec = pd.merge(n_desertores, n_matriculados, how="left")
porc_dec["%"] = porc_dec["n_desertores"] / porc_dec["n_matriculados"] * 100
porc_dec
# Out:
#    anio_desercion  n_desertores  n_matriculados          %
# 0            2016       30421.0          185799  16.373070
# 1            2017       44776.0          310538  14.418847
# 2            2018       51337.0          384231  13.360973
# 3            2019       58247.0          445920  13.062208
# 4            2020       71744.0          476106  15.068913
# 5            2021       78028.0          460630  16.939409
# 6            2022      119358.0          483290  24.696973

# %%
plt.figure(figsize=(12, 6))
plt.plot(porc_dec["anio_desercion"], porc_dec["%"], "-o", ms=15, color="royalblue", label="Años considerados");
plt.plot([2021, 2022], porc_dec[-2:]["%"], "-o", ms=15, color="dimgray", label="Años omitidos");
plt.title("% Deserción por año en CFT/IP");
plt.ylabel("% Deserción");
plt.xlabel("Año");

for a, porc in zip(porc_dec["anio_desercion"], porc_dec["%"]):
    correccion = -0.9 if a in [2021, 2022] else 0.5
    plt.annotate(round(porc, 1), (a, porc + correccion))

plt.legend();

# %%
unicos = df[df["anio_desercion"] < 2021].drop(columns="anio_desercion").drop_duplicates().sort_values(by=["desertor_1"], ascending=False).drop_duplicates(subset=["mrun"])
vc = unicos[["mrun", "codigo_unico"]].value_counts()
vc[vc>1]
# Out:
# Series([], dtype: int64)

# %%
df[df["mrun"]==10201104.0]
# Out:
#          cat_periodo     codigo_unico        mrun  gen_alu  fec_nac_alu  \
# 75897           2015  I143S23C609J2V1  10201104.0        2       199501
# 312552          2016  I143S23C609J2V1  10201104.0        2       199501
# 652591          2017  I143S23C609J2V1  10201104.0        2       199501
# 1061603         2018  I143S23C609J2V1  10201104.0        2       199501
#
#          anio_ing_carr_ori               tipo_inst_1    region_sede  \
# 75897                 2015  Institutos Profesionales  Metropolitana
# 312552                2015  Institutos Profesionales  Metropolitana
# 652591                2015  Institutos Profesionales  Metropolitana
# 1061603               2015  Institutos Profesionales  Metropolitana
#
#          valor_arancel          area_conocimiento acreditada_carr  \
# 75897        1590000.0  Administración y Comercio   NO ACREDITADA
# 312552       1900000.0  Administración y Comercio   NO ACREDITADA
# 652591       2000000.0  Administración y Comercio      ACREDITADA
# 1061603      2210000.0  Administración y Comercio      ACREDITADA
#
#         acreditada_inst  desertor_1 region_colegio  tipo_ensenanza_colegio  \
# 75897        ACREDITADA         0.0             13                   610.0
# 312552       ACREDITADA         0.0             13                   610.0
# 652591       ACREDITADA         0.0           13.0                   610.0
# 1061603      ACREDITADA         1.0           13.0                   610.0
#
#          prom_notas_media dependencia_colegio  cant_becas  anio_desercion
# 75897               5.075                 3.0         0.0            2016
# 312552              5.075                 3.0         0.0            2017
# 652591              5.075                 3.0         0.0            2018
# 1061603             5.075                   3         0.0            2019

# %%
(unicos["desertor_1"].value_counts("%") * 100)
# Out:
# 0.0    70.183758
# 1.0    29.816242
# Name: desertor_1, dtype: float64

# %%
(unicos["desertor_1"].value_counts("%") * 100).plot(kind="bar", figsize=(4, 4));
plt.xticks([0.0, 1.0], ["No desertor", "Desertor"]);
plt.xticks(rotation=0);
plt.ylim([0, 100]);
plt.annotate(70.1, (0.0, 71), ha="center");
plt.annotate(29.8, (1.0, 30), ha="center");
plt.ylabel("% Deserción");
plt.title("% Desertores CFT/IP en \nventana 2016-2020");

# %%
unicos.head()
# Out:
#          cat_periodo     codigo_unico        mrun  gen_alu  fec_nac_alu  \
# 1802593         2019     I139S3C7J2V1  25969377.0        2       199808
# 304221          2016   I111S5C141J2V1   9545401.0        2       197111
# 752751          2017    I126S7C23J1V1  16738237.0        2       198811
# 304236          2016  I143S23C118J2V2   9546342.0        1       199110
# 304235          2016  I430S10C138J2V2   9546296.0        1       199410
#
#          anio_ing_carr_ori                   tipo_inst_1    region_sede  \
# 1802593               2019      Institutos Profesionales         Biobío
# 304221                2016      Institutos Profesionales  Metropolitana
# 752751                2015      Institutos Profesionales   La Araucanía
# 304236                2015      Institutos Profesionales  Metropolitana
# 304235                2016  Centros de Formación Técnica  Metropolitana
#
#          valor_arancel          area_conocimiento acreditada_carr  \
# 1802593      1630000.0  Administración y Comercio      ACREDITADA
# 304221       1990000.0  Administración y Comercio      ACREDITADA
# 752751       1132500.0  Administración y Comercio   NO ACREDITADA
# 304236       1400000.0  Administración y Comercio      ACREDITADA
# 304235       1700000.0                 Tecnología      ACREDITADA
#
#         acreditada_inst  desertor_1 region_colegio  tipo_ensenanza_colegio  \
# 1802593      ACREDITADA         1.0            NaN                     NaN
# 304221       ACREDITADA         1.0            NaN                     NaN
# 752751       ACREDITADA         1.0              9                   410.0
# 304236       ACREDITADA         1.0             13                   310.0
# 304235       ACREDITADA         1.0             13                   510.0
#
#          prom_notas_media dependencia_colegio  cant_becas Desertor
# 1802593               NaN                 NaN         0.0      1.0
# 304221                NaN                 NaN         0.0      1.0
# 752751              4.925                 3.0         0.0      1.0
# 304236              5.375                 3.0         0.0      1.0
# 304235              4.500                 1.0         0.0      1.0

# %%
from pandas.plotting import parallel_coordinates
unicos["Desertor"] = unicos["desertor_1"].replace([0.0, 0.1], ["No desertor","Desertor"])
parallel_coordinates(unicos[["gen_alu", "prom_notas_media", "Desertor"]].dropna(), 'Desertor')

# %% [markdown]
# # Exploración nulos

# %%
df.isna().sum() / df.shape[0] * 100
# Out:
# cat_periodo                0.000000
# codigo_unico               0.000000
# mrun                       0.000000
# gen_alu                    0.000000
# fec_nac_alu                0.000000
# anio_ing_carr_ori          0.000000
# tipo_inst_1                0.000000
# region_sede                0.000000
# valor_arancel              0.000000
# area_conocimiento          0.000000
# acreditada_carr            0.000000
# acreditada_inst            0.000000
# desertor_1                 0.000000
# region_colegio            12.708874
# tipo_ensenanza_colegio    12.708874
# prom_notas_media          12.708874
# dependencia_colegio       12.990394
# cant_becas                 0.000000
# dtype: float64

# %% [markdown]
# ## Procesamiento

# %%
df["fec_nac_alu"] = df["fec_nac_alu"].replace([190001], [np.nan])
df["anio_ing_carr_ori"] = df["anio_ing_carr_ori"].replace([9995], [np.nan])
df["acreditada_carr"] = df["acreditada_carr"].str.strip().replace(["", "SIN INFORMACION"], [np.nan, np.nan])
df["acreditada_inst"] = df["acreditada_inst"].str.strip().replace([""], [np.nan])

# %%
msno.matrix(df);

# %%
df.isna().sum() / df.shape[0] * 100
# Out:
# cat_periodo                0.000000
# codigo_unico               0.000000
# mrun                       0.000000
# gen_alu                    0.000000
# fec_nac_alu                0.001493
# anio_ing_carr_ori          0.000000
# tipo_inst_1                0.000000
# region_sede                0.000000
# valor_arancel              0.000000
# area_conocimiento          0.000000
# acreditada_carr            0.000000
# acreditada_inst            0.000000
# desertor_1                 0.000000
# region_colegio            12.708874
# tipo_ensenanza_colegio    12.708874
# prom_notas_media          12.708874
# dependencia_colegio       12.990394
# cant_becas                 0.000000
# dtype: float64

# %%
ruts_unicos = df.drop_duplicates(subset=["mrun"])
msno.matrix(ruts_unicos);

# %%
ruts_unicos.isna().sum() / ruts_unicos.shape[0] * 100
# Out:
# cat_periodo                0.000000
# codigo_unico               0.000000
# mrun                       0.000000
# gen_alu                    0.000000
# fec_nac_alu                0.002420
# anio_ing_carr_ori          0.000000
# tipo_inst_1                0.000000
# region_sede                0.000000
# valor_arancel              0.000000
# area_conocimiento          0.000000
# acreditada_carr            0.000000
# acreditada_inst            0.000000
# desertor_1                 0.000000
# region_colegio            13.876706
# tipo_ensenanza_colegio    13.876706
# prom_notas_media          13.876706
# dependencia_colegio       14.192922
# cant_becas                 0.000000
# dtype: float64

# %% [markdown]
# ## Exploración variables en datos nulos

# %%
df_nan = ruts_unicos[ruts_unicos.isna().any(axis=1)].copy().dropna(subset=["fec_nac_alu"])

# %%
df_nan["anio_nac_alu_mas_18"] = df_nan["fec_nac_alu"].astype(str).str[:4].astype(int) + 18
df_nan["anio_nac_alu_mas_18"].describe()
# Out:
# count    164208.000000
# mean       1996.563919
# std           8.177410
# min        1948.000000
# 25%        1992.000000
# 50%        1997.000000
# 75%        2000.000000
# max        2022.000000
# Name: anio_nac_alu_mas_18, dtype: float64

# %%
perdidos = df_nan[df_nan["anio_nac_alu_mas_18"] < 1992]
perdidos.shape[0] / df_nan.shape[0] * 100
# Out:
# 23.609081165351263

# %%
perdidos.shape[0] / df.shape[0] * 100
# Out:
# 1.4115347673450782

# %%
pd.DataFrame(perdidos["region_sede"].value_counts("%") * 100,).rename(columns={"region_sede": "% matriculados sin info colegio"})
# Out:
#                         % matriculados sin info colegio
# Metropolitana                                 61.285080
# Valparaíso                                     9.309224
# Biobío                                         8.963578
# Maule                                          3.213991
# Coquimbo                                       2.925093
# Lib. Gral B. O'Higgins                         2.321502
# Los Lagos                                      2.306026
# La Araucanía                                   2.228642
# Antofagasta                                    2.048081
# Ñuble                                          1.617313
# Arica y Parinacota                             0.954395
# Los Ríos                                       0.895068
# Tarapacá                                       0.853797
# Atacama                                        0.508151
# Magallanes                                     0.348225
# Aysén                                          0.221832

# %%
df.dropna()["region_sede"].value_counts("%") * 100
# Out:
# Metropolitana             46.358248
# Valparaíso                10.059149
# Biobío                     9.410411
# Maule                      5.313939
# Coquimbo                   4.547446
# Lib. Gral B. O'Higgins     4.463419
# Los Lagos                  4.283063
# La Araucanía               4.273229
# Antofagasta                3.171089
# Ñuble                      2.081001
# Los Ríos                   1.541146
# Tarapacá                   1.316768
# Arica y Parinacota         1.203407
# Atacama                    0.973798
# Magallanes                 0.656522
# Aysén                      0.347364
# Name: region_sede, dtype: float64
